# %%
import datetime
import pandas as pd
import numpy as np

# %%
df_train = pd.read_hdf("data/train_preprocessed_v4.h5", low_memory = False)
df_train.head()
# Out:
#    fare_amount  pickup_longitude  pickup_latitude  dropoff_longitude  \
# 0          7.5        -73.978463        40.759072         -73.963577
# 1          6.5        -73.982397        40.770245         -73.972450
# 2         12.9        -74.006507        40.718808         -73.961096
# 3         20.1        -73.999242        40.734165         -73.972597
# 4          4.1        -73.977750        40.746274         -73.972760
#
#    dropoff_latitude  passenger_count    year  month  weekday  hour  distance  \
# 0         40.774255                1  2014.0      9        6    15  1.719640
# 1         40.764062                1  2012.0      5        1     7  1.122217
# 2         40.760711                1  2009.0      5        2    20  5.210553
# 3         40.751228                2  2010.0      7        4    22  3.008668
# 4         40.755768                1  2010.0      8        2    13  0.626738
#
#    JFK_distance  invalid
# 0     21.029044        0
# 1     21.940741        0
# 2     20.679895        0
# 3     21.891888        0
# 4     21.931951        0

# %%
taxi = df_train

# %%
taxi = taxi.drop(columns = ['passenger_count'])

# %%
taxi.head()
# Out:
#    fare_amount  pickup_longitude  pickup_latitude  dropoff_longitude  \
# 0          7.5        -73.978463        40.759072         -73.963577
# 1          6.5        -73.982397        40.770245         -73.972450
# 2         12.9        -74.006507        40.718808         -73.961096
# 3         20.1        -73.999242        40.734165         -73.972597
# 4          4.1        -73.977750        40.746274         -73.972760
#
#    dropoff_latitude    year  month  weekday  hour  distance  JFK_distance  \
# 0         40.774255  2014.0      9        6    15  1.719640     21.029044
# 1         40.764062  2012.0      5        1     7  1.122217     21.940741
# 2         40.760711  2009.0      5        2    20  5.210553     20.679895
# 3         40.751228  2010.0      7        4    22  3.008668     21.891888
# 4         40.755768  2010.0      8        2    13  0.626738     21.931951
#
#    invalid
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0

# %%
taxi = taxi.dropna()

# %%
taxi = taxi[taxi.fare_amount != 'fare_amount']

# %%
taxi['pickup_latitude'] = pd.to_numeric(taxi['pickup_latitude'])
taxi['pickup_longitude'] = pd.to_numeric(taxi['pickup_longitude'])
taxi['dropoff_latitude'] = pd.to_numeric(taxi['dropoff_latitude'])
taxi['dropoff_longitude'] = pd.to_numeric(taxi['dropoff_longitude'])
taxi['fare_amount'] = pd.to_numeric(taxi['fare_amount'])
taxi['passenger_count'] = pd.to_numeric(taxi['passenger_count'])

# %%
taxi = taxi[taxi['passenger_count'] <= 6]

# %%
def hours_after_midnight(date_time):
    time = date_time.split(' ')
    if len(time) == 3:
        time_arr = time[1].split(':')
        hours_after_midnight = int(time_arr[0]) 
        return hours_after_midnight
    else:
        return np.nan

def day_of_week(date_time):
    time = date_time.split(' ')
    if len(time) == 3:
        date_arr = time[0].split('-')
        date = datetime.date(int(date_arr[0]), int(date_arr[1]), int(date_arr[2]))
        return (date.weekday() + 1)
    else:
        return np.nan

def month(date_time):
    time = date_time.split(' ')
    if len(time) == 3:
        return int(time[0].split('-')[1])
    else:
        return np.nan

def year(date_time):
    time = date_time.split(' ')
    if len(time) == 3:
        return float(time[0].split('-')[0])
    else:
        return np.nan

hour_of_day_vec = np.vectorize(hours_after_midnight)
day_of_week_vec = np.vectorize(day_of_week)
month_vec = np.vectorize(month)
year_vec = np.vectorize(year)

# %%
time_column = taxi['pickup_datetime'].to_numpy()
taxi.drop(columns = ['pickup_datetime', 'key'], inplace = True)

# %%
taxi['year'] = year_vec(time_column)
taxi['month'] = month_vec(time_column)
taxi['weekday'] = day_of_week_vec(time_column)
taxi['hour'] = hour_of_day_vec(time_column)

# %%
from math import radians, cos, sin, asin, sqrt
import numpy as np

def haversine_np(lon1, lat1, lon2, lat2):
    """
    Calculate the great circle distance between two points
    on the earth (specified in decimal degrees)

    All args must be of equal length.    

    """
    lon1, lat1, lon2, lat2 = map(np.radians, [lon1, lat1, lon2, lat2])

    dlon = lon2 - lon1
    dlat = lat2 - lat1

    a = np.sin(dlat/2.0)**2 + np.cos(lat1) * np.cos(lat2) * np.sin(dlon/2.0)**2

    c = 2 * np.arcsin(np.sqrt(a))
    km = 6371 * c  # 6371 is Radius of earth in kilometers. Use 3956 for miles
    return km

taxi['distance'] = haversine_np(taxi['pickup_latitude'], taxi['pickup_longitude'], taxi['dropoff_latitude'] , taxi['dropoff_longitude'])

# %%
JFK_coord = (40.6413, -73.7781)
pickup_JFK = haversine_np(taxi['pickup_latitude'], taxi['pickup_longitude'], JFK_coord[0], JFK_coord[1]) 
dropoff_JFK = haversine_np(JFK_coord[0], JFK_coord[1], taxi['dropoff_latitude'], taxi['dropoff_longitude'])
taxi['JFK_distance'] = pd.concat([pickup_JFK, dropoff_JFK], axis=1).min(axis=1)
taxi.head()
# Out:
#    fare_amount  pickup_longitude  pickup_latitude  dropoff_longitude  \
# 0          7.5        -73.978463        40.759072         -73.963577
# 1          6.5        -73.982397        40.770245         -73.972450
# 2         12.9        -74.006507        40.718808         -73.961096
# 3         20.1        -73.999242        40.734165         -73.972597
# 4          4.1        -73.977750        40.746274         -73.972760
#
#    dropoff_latitude  passenger_count    year  month  weekday  hour  distance  \
# 0         40.774255                1  2014.0      9        6    15  1.719640
# 1         40.764062                1  2012.0      5        1     7  1.122217
# 2         40.760711                1  2009.0      5        2    20  5.210553
# 3         40.751228                2  2010.0      7        4    22  3.008668
# 4         40.755768                1  2010.0      8        2    13  0.626738
#
#    JFK_distance
# 0     21.029044
# 1     21.940741
# 2     20.679895
# 3     21.891888
# 4     21.931951

# %%
taxi = taxi[taxi['distance'] > 0]

# %%
def is_valid(p_lat, p_long, d_lat, d_long):
    bounds = (-74.5, -72.8, 40.5, 41.8)
    if ((p_long >= bounds[0]) & (p_long <= bounds[1]) & (p_lat >= bounds[2]) & (p_lat <= bounds[3])):
        if (d_long >= bounds[0]) & (d_long <= bounds[1]) & (d_lat >= bounds[2]) & (d_lat <= bounds[3]):
            return 0
    return 1

valid_vec = np.vectorize(is_valid)
taxi['invalid'] = valid_vec(taxi['pickup_latitude'], taxi['pickup_longitude'], taxi['dropoff_latitude'], taxi['dropoff_longitude'])
taxi.head()
# Out:
#    fare_amount  pickup_longitude  pickup_latitude  dropoff_longitude  \
# 0          7.5        -73.978463        40.759072         -73.963577
# 1          6.5        -73.982397        40.770245         -73.972450
# 2         12.9        -74.006507        40.718808         -73.961096
# 3         20.1        -73.999242        40.734165         -73.972597
# 4          4.1        -73.977750        40.746274         -73.972760
#
#    dropoff_latitude  passenger_count    year  month  weekday  hour  distance  \
# 0         40.774255                1  2014.0      9        6    15  1.719640
# 1         40.764062                1  2012.0      5        1     7  1.122217
# 2         40.760711                1  2009.0      5        2    20  5.210553
# 3         40.751228                2  2010.0      7        4    22  3.008668
# 4         40.755768                1  2010.0      8        2    13  0.626738
#
#    JFK_distance  invalid
# 0     21.029044        0
# 1     21.940741        0
# 2     20.679895        0
# 3     21.891888        0
# 4     21.931951        0

# %%
import matplotlib.pyplot as plt
nyc_bounds = (-74.5, -72.8, 40.5, 41.8)

def select_within_bounds(df, bounds):
    pickup_indices = (df.pickup_longitude >= bounds[0]) & (df.pickup_longitude <= bounds[1]) & \
        (df.pickup_latitude >= bounds[2]) & (df.pickup_latitude <= bounds[3])

    dropoff_indices = (df.dropoff_longitude >= bounds[0]) & (df.dropoff_longitude <= bounds[1]) & \
        (df.dropoff_latitude >= bounds[2]) & (df.dropoff_latitude <= bounds[3])

    return pickup_indices & dropoff_indices

def map_to_nyc_mask(longitude, latitude, points_x, points_y, bounds):
    x = (points_x * (longitude - bounds[0]) / (bounds[1] - bounds[0])).astype('int')
    y = (points_y - points_y * (latitude - bounds[2]) / (bounds[3] - bounds[2])).astype('int')
    return x,y

def remove_points_in_water(df):
    # Create a mask of the New York City with 1 as land and 0 as water
    nyc_mask = plt.imread('img/nyc_water_mask.png')[:,:,0] > 0.9

    # Remove points outside New York
    df = df[select_within_bounds(df, nyc_bounds)]
    print("After Bounds:", df.shape[0])

    # Map the latitudes and longitudes to the points in the map
    pickup_x, pickup_y = map_to_nyc_mask(df.pickup_longitude, df.pickup_latitude, nyc_mask.shape[1],
                                         nyc_mask.shape[0], nyc_bounds)
    dropoff_x, dropoff_y = map_to_nyc_mask(df.dropoff_longitude, df.dropoff_latitude, nyc_mask.shape[1],
                                        nyc_mask.shape[0], nyc_bounds)
    
    pickup_y[pickup_y == 1262] = 1261
    dropoff_y[dropoff_y == 1262] = 1261
    pickup_x[pickup_x == 1242] = 1241
    dropoff_x[dropoff_x == 1242] = 1241

    # Compute the indices where pickup and dropoff locations are on land
    indices = nyc_mask[pickup_y, pickup_x] & nyc_mask[dropoff_y, dropoff_x]

    df = df[indices]
    print("Number of trips in water: ", np.sum(~indices))
    return df

# %%
def make_invalid_water(invalid_col):
    if (invalid_col == 1):
        return 1
    else:
        return 2
inv_vec = np.vectorize(make_invalid_water)

def get_water_invalid(df):
    df2 = remove_points_in_water(df)
    df_diff = pd.concat([df, df2])
    print("Concatenated dataframes")
    df_diff = df_diff.drop_duplicates(keep=False)
    print("dropped duplicates")
    df_diff['invalid'] = inv_vec(df_diff.invalid)
    df = pd.concat([df2, df_diff])
    df.reset_index(inplace = True)
    return df

# %%
taxi = get_water_invalid(taxi)
# Out:
# After Bounds: 42940936
# Number of trips in water:  8402
# Concatenated dataframes
# dropped duplicates

# %%
taxi.drop(columns = ['index'], inplace = True)
taxi.shape
# Out:
# (43074441, 13)

# %%
taxi.to_hdf(r'data/train_preprocessed_v4.h5', 'data')

# %%
from sklearn.model_selection import train_test_split
y = taxi['fare_amount']
X = taxi.drop(columns=['fare_amount'])
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=40)

# %%
import lightgbm as lgb

params = {
        'learning_rate': 0.65,
        'application': 'regression',
        'max_depth': 3,
        'num_leaves': 200,
        'verbosity': -1,
        'metric': 'RMSE',
    }

# %%
lgb_train = lgb.Dataset(X_train, y_train)
lgb_eval = lgb.Dataset(X_test, y_test, reference=lgb_train)
gbm = lgb.train(params,
                lgb_train,
                valid_sets=lgb_eval,
                num_boost_round=300)
gbm.save_model('model_v9.txt')
# Out:
# [1]	valid_0's rmse: 21.856
# [2]	valid_0's rmse: 21.6396
# [3]	valid_0's rmse: 21.5651
# [4]	valid_0's rmse: 21.5336
# [5]	valid_0's rmse: 21.5164
# [6]	valid_0's rmse: 21.488
# [7]	valid_0's rmse: 21.4791
# [8]	valid_0's rmse: 21.4709
# [9]	valid_0's rmse: 21.4645
# [10]	valid_0's rmse: 21.46
# [11]	valid_0's rmse: 21.4524
# [12]	valid_0's rmse: 21.4455
# [13]	valid_0's rmse: 21.4418
# [14]	valid_0's rmse: 21.433
# [15]	valid_0's rmse: 21.431
# [16]	valid_0's rmse: 21.4229
# [17]	valid_0's rmse: 21.4197
# [18]	valid_0's rmse: 21.4134
# [19]	valid_0's rmse: 21.4111
# [20]	valid_0's rmse: 21.4077
# [21]	valid_0's rmse: 21.4043
# [22]	valid_0's rmse: 21.4034
# [23]	valid_0's rmse: 21.4005
# [24]	valid_0's rmse: 21.3987
# [25]	valid_0's rmse: 21.3972
# [26]	valid_0's rmse: 21.3961
# [27]	valid_0's rmse: 21.3951
# [28]	valid_0's rmse: 21.3941
# [29]	valid_0's rmse: 21.3924
# [30]	valid_0's rmse: 21.3912
# [31]	valid_0's rmse: 21.3898
# [32]	valid_0's rmse: 21.389
# [33]	valid_0's rmse: 21.3877
# [34]	valid_0's rmse: 21.3866
# [35]	valid_0's rmse: 21.384
# [36]	valid_0's rmse: 21.3817
# [37]	valid_0's rmse: 21.3808
# [38]	valid_0's rmse: 21.38
# [39]	valid_0's rmse: 21.3796
# [40]	valid_0's rmse: 21.3792
# [41]	valid_0's rmse: 21.3788
# [42]	valid_0's rmse: 21.376
# [43]	valid_0's rmse: 21.3742
# [44]	valid_0's rmse: 21.3736
# [45]	valid_0's rmse: 21.3734
# [46]	valid_0's rmse: 21.3723
# [47]	valid_0's rmse: 21.3715
# [48]	valid_0's rmse: 21.3707
# [49]	valid_0's rmse: 21.3703
# [50]	valid_0's rmse: 21.3658
# [51]	valid_0's rmse: 21.3638
# [52]	valid_0's rmse: 21.3632
# [53]	valid_0's rmse: 21.3623
# [54]	valid_0's rmse: 21.3612
# [55]	valid_0's rmse: 21.3607
# [56]	valid_0's rmse: 21.3598
# [57]	valid_0's rmse: 21.3593
# [58]	valid_0's rmse: 21.3578
# [59]	valid_0's rmse: 21.3573
# [60]	valid_0's rmse: 21.3568
# [61]	valid_0's rmse: 21.3566
# [62]	valid_0's rmse: 21.3554
# [63]	valid_0's rmse: 21.3544
# [64]	valid_0's rmse: 21.354
# [65]	valid_0's rmse: 21.3533
# [66]	valid_0's rmse: 21.3529
# [67]	valid_0's rmse: 21.3523
# [68]	valid_0's rmse: 21.352
# [69]	valid_0's rmse: 21.3516
# [70]	valid_0's rmse: 21.3506
# [71]	valid_0's rmse: 21.3501
# [72]	valid_0's rmse: 21.3496
# [73]	valid_0's rmse: 21.3492
# [74]	valid_0's rmse: 21.3497
# [75]	valid_0's rmse: 21.3492
# [76]	valid_0's rmse: 21.3487
# [77]	valid_0's rmse: 21.3482
# [78]	valid_0's rmse: 21.348
# [79]	valid_0's rmse: 21.3478
# [80]	valid_0's rmse: 21.3472
# [81]	valid_0's rmse: 21.3471
# [82]	valid_0's rmse: 21.3467
# [83]	valid_0's rmse: 21.3464
# [84]	valid_0's rmse: 21.346
# [85]	valid_0's rmse: 21.3455
# [86]	valid_0's rmse: 21.3452
# [87]	valid_0's rmse: 21.345
# [88]	valid_0's rmse: 21.3442
# [89]	valid_0's rmse: 21.3433
# [90]	valid_0's rmse: 21.343
# [91]	valid_0's rmse: 21.3427
# [92]	valid_0's rmse: 21.3424
# [93]	valid_0's rmse: 21.3421
# [94]	valid_0's rmse: 21.3419
# [95]	valid_0's rmse: 21.3418
# [96]	valid_0's rmse: 21.3414
# [97]	valid_0's rmse: 21.3412
# [98]	valid_0's rmse: 21.3408
# [99]	valid_0's rmse: 21.3402
# [100]	valid_0's rmse: 21.3399
# [101]	valid_0's rmse: 21.3394
# [102]	valid_0's rmse: 21.3389
# [103]	valid_0's rmse: 21.3386
# [104]	valid_0's rmse: 21.3385
# [105]	valid_0's rmse: 21.3381
# [106]	valid_0's rmse: 21.3378
# [107]	valid_0's rmse: 21.3376
# [108]	valid_0's rmse: 21.3373
# [109]	valid_0's rmse: 21.337
# [110]	valid_0's rmse: 21.3368
# [111]	valid_0's rmse: 21.3366
# [112]	valid_0's rmse: 21.3363
# [113]	valid_0's rmse: 21.336
# [114]	valid_0's rmse: 21.3358
# [115]	valid_0's rmse: 21.3357
# [116]	valid_0's rmse: 21.3353
# [117]	valid_0's rmse: 21.335
# [118]	valid_0's rmse: 21.3346
# [119]	valid_0's rmse: 21.3343
# [120]	valid_0's rmse: 21.3339
# [121]	valid_0's rmse: 21.3337
# [122]	valid_0's rmse: 21.3333
# [123]	valid_0's rmse: 21.333
# [124]	valid_0's rmse: 21.3328
# [125]	valid_0's rmse: 21.3324
# [126]	valid_0's rmse: 21.3322
# [127]	valid_0's rmse: 21.332
# [128]	valid_0's rmse: 21.3318
# [129]	valid_0's rmse: 21.3316
# [130]	valid_0's rmse: 21.3314
# [131]	valid_0's rmse: 21.3309
# [132]	valid_0's rmse: 21.3308
# [133]	valid_0's rmse: 21.3306
# [134]	valid_0's rmse: 21.3307
# [135]	valid_0's rmse: 21.3306
# [136]	valid_0's rmse: 21.3304
# [137]	valid_0's rmse: 21.3303
# [138]	valid_0's rmse: 21.3301
# [139]	valid_0's rmse: 21.33
# [140]	valid_0's rmse: 21.3296
# [141]	valid_0's rmse: 21.3295
# [142]	valid_0's rmse: 21.3293
# [143]	valid_0's rmse: 21.3292
# [144]	valid_0's rmse: 21.3289
# [145]	valid_0's rmse: 21.3287
# [146]	valid_0's rmse: 21.3287
# [147]	valid_0's rmse: 21.3284
# [148]	valid_0's rmse: 21.3283
# [149]	valid_0's rmse: 21.3281
# [150]	valid_0's rmse: 21.3279
# [151]	valid_0's rmse: 21.3277
# [152]	valid_0's rmse: 21.3276
# [153]	valid_0's rmse: 21.3274
# [154]	valid_0's rmse: 21.3273
# [155]	valid_0's rmse: 21.3272
# [156]	valid_0's rmse: 21.3269
# [157]	valid_0's rmse: 21.3268
# [158]	valid_0's rmse: 21.3266
# [159]	valid_0's rmse: 21.3264
# [160]	valid_0's rmse: 21.3263
# [161]	valid_0's rmse: 21.3262
# [162]	valid_0's rmse: 21.3265
# [163]	valid_0's rmse: 21.3264
# [164]	valid_0's rmse: 21.3262
# [165]	valid_0's rmse: 21.3261
# [166]	valid_0's rmse: 21.3258
# [167]	valid_0's rmse: 21.3257
# [168]	valid_0's rmse: 21.326
# [169]	valid_0's rmse: 21.3257
# [170]	valid_0's rmse: 21.3256
# [171]	valid_0's rmse: 21.3255
# [172]	valid_0's rmse: 21.3254
# [173]	valid_0's rmse: 21.3253
# [174]	valid_0's rmse: 21.3252
# [175]	valid_0's rmse: 21.325
# [176]	valid_0's rmse: 21.3249
# [177]	valid_0's rmse: 21.3247
# [178]	valid_0's rmse: 21.3246
# [179]	valid_0's rmse: 21.3244
# [180]	valid_0's rmse: 21.324
# [181]	valid_0's rmse: 21.3238
# [182]	valid_0's rmse: 21.3237
# [183]	valid_0's rmse: 21.3236
# [184]	valid_0's rmse: 21.3234
# [185]	valid_0's rmse: 21.3233
# [186]	valid_0's rmse: 21.3232
# [187]	valid_0's rmse: 21.3231
# [188]	valid_0's rmse: 21.3229
# [189]	valid_0's rmse: 21.3232
# [190]	valid_0's rmse: 21.3228
# [191]	valid_0's rmse: 21.3227
# [192]	valid_0's rmse: 21.3227
# [193]	valid_0's rmse: 21.3224
# [194]	valid_0's rmse: 21.3223
# [195]	valid_0's rmse: 21.3222
# [196]	valid_0's rmse: 21.322
# [197]	valid_0's rmse: 21.322
# [198]	valid_0's rmse: 21.322
# [199]	valid_0's rmse: 21.3218
# [200]	valid_0's rmse: 21.3218
# [201]	valid_0's rmse: 21.3217
# [202]	valid_0's rmse: 21.3216
# [203]	valid_0's rmse: 21.3215
# [204]	valid_0's rmse: 21.3214
# [205]	valid_0's rmse: 21.3213
# [206]	valid_0's rmse: 21.3211
# [207]	valid_0's rmse: 21.3212
# [208]	valid_0's rmse: 21.3211
# [209]	valid_0's rmse: 21.321
# [210]	valid_0's rmse: 21.3208
# [211]	valid_0's rmse: 21.3207
# [212]	valid_0's rmse: 21.3206
# [213]	valid_0's rmse: 21.3206
# [214]	valid_0's rmse: 21.3206
# [215]	valid_0's rmse: 21.3205
# [216]	valid_0's rmse: 21.3215
# [217]	valid_0's rmse: 21.3214
# [218]	valid_0's rmse: 21.3214
# [219]	valid_0's rmse: 21.3212
# [220]	valid_0's rmse: 21.3211
# [221]	valid_0's rmse: 21.3211
# [222]	valid_0's rmse: 21.321
# [223]	valid_0's rmse: 21.3208
# [224]	valid_0's rmse: 21.3207
# [225]	valid_0's rmse: 21.3206
# [226]	valid_0's rmse: 21.3208
# [227]	valid_0's rmse: 21.3205
# [228]	valid_0's rmse: 21.3204
# [229]	valid_0's rmse: 21.3204
# [230]	valid_0's rmse: 21.3204
# [231]	valid_0's rmse: 21.3204
# [232]	valid_0's rmse: 21.3202
# [233]	valid_0's rmse: 21.3201
# [234]	valid_0's rmse: 21.32
# [235]	valid_0's rmse: 21.3198
# [236]	valid_0's rmse: 21.3198
# [237]	valid_0's rmse: 21.3196
# [238]	valid_0's rmse: 21.3194
# [239]	valid_0's rmse: 21.3194
# [240]	valid_0's rmse: 21.3192
# [241]	valid_0's rmse: 21.3191
# [242]	valid_0's rmse: 21.319
# [243]	valid_0's rmse: 21.3188
# [244]	valid_0's rmse: 21.3188
# [245]	valid_0's rmse: 21.3188
# [246]	valid_0's rmse: 21.3187
# [247]	valid_0's rmse: 21.3186
# [248]	valid_0's rmse: 21.3188
# [249]	valid_0's rmse: 21.3187
# [250]	valid_0's rmse: 21.3187
# [251]	valid_0's rmse: 21.3186
# [252]	valid_0's rmse: 21.3184
# [253]	valid_0's rmse: 21.3184
# [254]	valid_0's rmse: 21.3183
# [255]	valid_0's rmse: 21.3182
# [256]	valid_0's rmse: 21.318
# [257]	valid_0's rmse: 21.318
# [258]	valid_0's rmse: 21.3182
# [259]	valid_0's rmse: 21.318
# [260]	valid_0's rmse: 21.318
# [261]	valid_0's rmse: 21.3179
# [262]	valid_0's rmse: 21.3178
# [263]	valid_0's rmse: 21.3177
# [264]	valid_0's rmse: 21.3176
# [265]	valid_0's rmse: 21.3173
# [266]	valid_0's rmse: 21.3172
# [267]	valid_0's rmse: 21.3171
# [268]	valid_0's rmse: 21.3169
# [269]	valid_0's rmse: 21.3169
# [270]	valid_0's rmse: 21.3168
# [271]	valid_0's rmse: 21.3167
# [272]	valid_0's rmse: 21.3167
# [273]	valid_0's rmse: 21.3166
# [274]	valid_0's rmse: 21.3166
# [275]	valid_0's rmse: 21.3165
# [276]	valid_0's rmse: 21.3165
# [277]	valid_0's rmse: 21.3165
# [278]	valid_0's rmse: 21.3164
# [279]	valid_0's rmse: 21.3162
# [280]	valid_0's rmse: 21.3162
# [281]	valid_0's rmse: 21.3161
# [282]	valid_0's rmse: 21.316
# [283]	valid_0's rmse: 21.3159
# [284]	valid_0's rmse: 21.3158
# [285]	valid_0's rmse: 21.3157
# [286]	valid_0's rmse: 21.3156
# [287]	valid_0's rmse: 21.3156
# [288]	valid_0's rmse: 21.3154
# [289]	valid_0's rmse: 21.3154
# [290]	valid_0's rmse: 21.3153
# [291]	valid_0's rmse: 21.3154
# [292]	valid_0's rmse: 21.3152
# [293]	valid_0's rmse: 21.3152
# [294]	valid_0's rmse: 21.315
# [295]	valid_0's rmse: 21.3149
# [296]	valid_0's rmse: 21.3153
# [297]	valid_0's rmse: 21.3153
# [298]	valid_0's rmse: 21.3152
# [299]	valid_0's rmse: 21.3151
# [300]	valid_0's rmse: 21.3162

# %%
df_test = pd.read_csv('data/test.csv', low_memory = False)
df_test.head()
# Out:
#                            key          pickup_datetime  pickup_longitude  \
# 0  2009-01-01 00:01:04.0000003  2009-01-01 00:01:04 UTC        -73.972484
# 1  2009-01-01 00:01:26.0000001  2009-01-01 00:01:26 UTC        -73.985850
# 2  2009-01-01 00:04:42.0000001  2009-01-01 00:04:42 UTC        -73.988917
# 3  2009-01-01 00:04:54.0000001  2009-01-01 00:04:54 UTC        -73.977163
# 4  2009-01-01 00:04:59.0000004  2009-01-01 00:04:59 UTC        -73.948849
#
#    pickup_latitude  dropoff_longitude  dropoff_latitude  passenger_count
# 0        40.742743         -73.918937         40.764496                1
# 1        40.722826         -73.986301         40.739347                1
# 2        40.740142         -73.982769         40.777291                1
# 3        40.764490         -73.914474         40.771575                1
# 4        40.778003         -73.977678         40.748692                2

# %%
time_column = df_test['pickup_datetime'].to_numpy()
df_test.drop(columns = ['pickup_datetime'], inplace = True)

# %%
df_test['year'] = year_vec(time_column)
df_test['month'] = month_vec(time_column)
df_test['weekday'] = day_of_week_vec(time_column)
df_test['hour'] = hour_of_day_vec(time_column)

# %%
pickup_JFK = haversine_np(df_test['pickup_latitude'], df_test['pickup_longitude'], JFK_coord[0], JFK_coord[1]) 
dropoff_JFK = haversine_np(JFK_coord[0], JFK_coord[1], df_test['dropoff_latitude'], df_test['dropoff_longitude'])
df_test['JFK_distance'] = pd.concat([pickup_JFK, dropoff_JFK], axis=1).min(axis=1)

# %%
df_test['distance'] = haversine_np(df_test['pickup_latitude'], df_test['pickup_longitude'], df_test['dropoff_latitude'] , df_test['dropoff_longitude'])

# %%
df_test['invalid'] = valid_vec(df_test['pickup_latitude'], df_test['pickup_longitude'], df_test['dropoff_latitude'], df_test['dropoff_longitude'])
df_test.head()
# Out:
#                            key  pickup_longitude  pickup_latitude  \
# 0  2009-01-01 00:01:04.0000003        -73.972484        40.742743
# 1  2009-01-01 00:01:26.0000001        -73.985850        40.722826
# 2  2009-01-01 00:04:42.0000001        -73.988917        40.740142
# 3  2009-01-01 00:04:54.0000001        -73.977163        40.764490
# 4  2009-01-01 00:04:59.0000004        -73.948849        40.778003
#
#    dropoff_longitude  dropoff_latitude  passenger_count    year  month  \
# 0         -73.918937         40.764496                1  2009.0      1
# 1         -73.986301         40.739347                1  2009.0      1
# 2         -73.982769         40.777291                1  2009.0      1
# 3         -73.914474         40.771575                1  2009.0      1
# 4         -73.977678         40.748692                2  2009.0      1
#
#    weekday  hour  distance  JFK_distance  invalid
# 0        4     0  5.991612     16.117319        0
# 1        4     0  0.509264     23.237424        0
# 2        4     0  1.328903     23.142153        0
# 3        4     0  6.974103     15.690509        0
# 4        4     0  3.329684     19.450750        0

# %%
df_test = get_water_invalid(df_test)
# Out:
# After Bounds: 10849338
# Number of trips in water:  2311
# Concatenated dataframes
# dropped duplicates

# %%
keys = df_test['key'] 
df_test.drop(columns = ['key'], inplace = True)
df_test.head()
# Out:
#    index  pickup_longitude  pickup_latitude  dropoff_longitude  \
# 0      0        -73.972484        40.742743         -73.918937
# 1      1        -73.985850        40.722826         -73.986301
# 2      2        -73.988917        40.740142         -73.982769
# 3      3        -73.977163        40.764490         -73.914474
# 4      4        -73.948849        40.778003         -73.977678
#
#    dropoff_latitude  passenger_count    year  month  weekday  hour  distance  \
# 0         40.764496                1  2009.0      1        4     0  5.991612
# 1         40.739347                1  2009.0      1        4     0  0.509264
# 2         40.777291                1  2009.0      1        4     0  1.328903
# 3         40.771575                1  2009.0      1        4     0  6.974103
# 4         40.748692                2  2009.0      1        4     0  3.329684
#
#    JFK_distance  invalid
# 0     16.117319        0
# 1     23.237424        0
# 2     23.142153        0
# 3     15.690509        0
# 4     19.450750        0

# %%
df_test.fillna(df_test.mean())
# Out:
#              index  pickup_longitude  pickup_latitude  dropoff_longitude  \
# 0                0        -73.972484        40.742743         -73.918937
# 1                1        -73.985850        40.722826         -73.986301
# 2                2        -73.988917        40.740142         -73.982769
# 3                3        -73.977163        40.764490         -73.914474
# 4                4        -73.948849        40.778003         -73.977678
# ...            ...               ...              ...                ...
# 11084767  11084429          0.000000         0.000000           0.000000
# 11084768  11084468          0.000000         0.000000           0.000000
# 11084769  11084635          0.000000         0.000000           0.000000
# 11084770  11084715          0.000000         0.000000           0.000000
# 11084771  11084731          0.000000         0.000000           0.000000
#
#           dropoff_latitude  passenger_count    year  month  weekday  hour  \
# 0                40.764496                1  2009.0      1        4     0
# 1                40.739347                1  2009.0      1        4     0
# 2                40.777291                1  2009.0      1        4     0
# 3                40.771575                1  2009.0      1        4     0
# 4                40.748692                2  2009.0      1        4     0
# ...                    ...              ...     ...    ...      ...   ...
# 11084767          0.000000                2  2015.0      6        2    22
# 11084768          0.000000                1  2015.0      6        2    22
# 11084769          0.000000                5  2015.0      6        2    23
# 11084770          0.000000                3  2015.0      6        2    23
# 11084771          0.000000                1  2015.0      6        2    23
#
#           distance  JFK_distance  invalid
# 0         5.991612     16.117319        0
# 1         0.509264     23.237424        0
# 2         1.328903     23.142153        0
# 3         6.974103     15.690509        0
# 4         3.329684     19.450750        0
# ...            ...           ...      ...
# 11084767  0.000000   8646.710415        1
# 11084768  0.000000   8646.710415        1
# 11084769  0.000000   8646.710415        1
# 11084770  0.000000   8646.710415        1
# 11084771  0.000000   8646.710415        1
#
# [11084772 rows x 13 columns]

# %%
df_test.drop(columns = ['index'], inplace = True)

# %%
df_test.head()
# Out:
#    pickup_longitude  pickup_latitude  dropoff_longitude  dropoff_latitude  \
# 0        -73.972484        40.742743         -73.918937         40.764496
# 1        -73.985850        40.722826         -73.986301         40.739347
# 2        -73.988917        40.740142         -73.982769         40.777291
# 3        -73.977163        40.764490         -73.914474         40.771575
# 4        -73.948849        40.778003         -73.977678         40.748692
#
#    passenger_count    year  month  weekday  hour  distance  JFK_distance  \
# 0                1  2009.0      1        4     0  5.991612     16.117319
# 1                1  2009.0      1        4     0  0.509264     23.237424
# 2                1  2009.0      1        4     0  1.328903     23.142153
# 3                1  2009.0      1        4     0  6.974103     15.690509
# 4                2  2009.0      1        4     0  3.329684     19.450750
#
#    invalid
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0

# %%
pred_fares = gbm.predict(df_test, num_iteration=gbm.best_iteration)
df_final = pd.DataFrame({'key':keys, 'fare_amount':pred_fares})

# %%
df_final.to_csv(r'predictions/lightgbm_withfeaures_v4.csv', index = False)

# %%
df_test['key'] = keys
df_test.to_hdf(r'data/test_prepro_v4.h5', 'data')
